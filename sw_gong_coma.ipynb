# %% [markdown]
# <a href="https://colab.research.google.com/github/ABolza/coma/blob/master/sw_gong_coma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sw gong mesh https://github.com/sw-gong/coma

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Installazione di MPI-IS mesh

# %% [markdown]
# https://github.com/MPI-IS/mesh

# %%
# !git clone https://github.com/MPI-IS/mesh
# Out:
# Cloning into 'mesh'...
# remote: Enumerating objects: 304, done.
# remote: Total 304 (delta 0), reused 0 (delta 0), pack-reused 304
# Receiving objects: 100% (304/304), 19.69 MiB | 46.36 MiB/s, done.
# Resolving deltas: 100% (151/151), done.

# %%
cd mesh
# Out:
# /content/mesh

# %%
# !apt-get install python3-venv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3.6-venv
# The following NEW packages will be installed:
#   python-pip-whl python3-venv python3.6-venv
# 0 upgraded, 3 newly installed, 0 to remove and 14 not upgraded.
# Need to get 1,660 kB of archives.
# After this operation, 1,902 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-pip-whl all 9.0.1-2.3~ubuntu1.18.04.4 [1,653 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3.6-venv amd64 3.6.9-1~18.04ubuntu1.3 [6,180 B]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-venv amd64 3.6.7-1~18.04 [1,208 B]
# Fetched 1,660 kB in 1s (2,094 kB/s)
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 144865 files and directories currently installed.)
# ...

# %%
# !python3 -m venv --copies my_venv

# %%
# !source my_venv/bin/activate

# %%
# !BOOST_INCLUDE_DIRS=/path/to/boost/include make all
# Out:
# ----- [ mesh_package ] Installing with the interpreter /usr/local/bin/python (version 3.6.9)
# ...
#      |████████████████████████████████| 788kB 13.1MB/s
# ...
#      |████████████████████████████████| 14.5MB 250kB/s
# ...
#      |████████████████████████████████| 11.6MB 149kB/s
# ...
#      |████████████████████████████████| 25.9MB 127kB/s
# Requirement already up-to-date: pyopengl in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (3.1.5)
# ...
#      |████████████████████████████████| 2.2MB 45.4MB/s
# Requirement already up-to-date: pyzmq in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (20.0.0)
# ...
#      |████████████████████████████████| 276kB 59.3MB/s
# ...
#      |████████████████████████████████| 49.5MB 65kB/s
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=c50f2595a8d81862ccf41484fe17479ddc79924ed9da98e206a291593eecec7a
# ...

# %% [markdown]
# #Installazione

# %%
# !pip install torch
# !pip install torch-sparse
# !pip install torch-scatter
# !pip install torch-geometric==1.4.3
# !pip install tqdm
# !pip install openmesh
# Out:
# ...
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.8-cp36-cp36m-linux_x86_64.whl size=23315356 sha256=065b3a15f810600cb6e0d8860dd8d0e6824e0efa6a690aeabcea8c150c7f78dc
#   Stored in directory: /root/.cache/pip/wheels/31/d3/94/e2560941994bebe665b1dccc69faf33d33aeee2bca353c9bcc
# Successfully built torch-sparse
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.5-cp36-cp36m-linux_x86_64.whl size=11774536 sha256=1a4e26b3409d282728376d5ec20e04dec96410fe7e919243edd4c07f8bb2d92a
#   Stored in directory: /root/.cache/pip/wheels/42/59/d3/9866e4fd8e1fe9260740acfe22322c428bc0dc064d3ebc456c
# Successfully built torch-scatter
# ...
#      |████████████████████████████████| 133kB 15.9MB/s
# ...
#      |████████████████████████████████| 235kB 13.6MB/s
# ...
#      |████████████████████████████████| 51kB 8.4MB/s
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-1.4.3-cp36-none-any.whl size=234874 sha256=5f68bcd0cd2e626b22b2f84ce235f0107d37f8a4d006cdec3077753b66004fe1
# ...

# %%
cd /content/

# %%
#cd /content/drive/My Drive/TESI/Esempio/COMA/sw_gong_coma
# Out:
# /content/drive/My Drive/TESI/Esempio/COMA/sw_gong_coma

# %%
# !git clone https://github.com/sw-gong/coma
# Out:
# Cloning into 'coma'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 47 (delta 10), reused 47 (delta 10), pack-reused 0
# Unpacking objects: 100% (47/47), done.

# %%
cd coma
# Out:
# /content/mesh/coma

# %% [markdown]
# #Experiment

# %%
#file_id = https://drive.google.com/drive/folders/1ZtCzWHO68F-8c04DAku0hvn3duJ5oM3X?usp=sharing
# !gdown --id  https://drive.google.com/drive/folders/1ZtCzWHO68F-8c04DAku0hvn3duJ5oM3X
# Out:
# Permission denied: https://drive.google.com/uc?id=https://drive.google.com/drive/folders/1ZtCzWHO68F-8c04DAku0hvn3duJ5oM3X
# Maybe you need to change permission over 'Anyone with the link'?

# %%
#!bash train_interpolation.sh

# %%
# !python main.py --exp_name 'interpolation_exp' --split 'interpolation' --device_idx 0
# Out:
# Namespace(K=6, batch_size=16, checkpoints_dir='/content/drive/My Drive/TESI/Esempio/COMA/sw_gong_coma/coma/out/interpolation_exp/checkpoints', data_fp='/content/drive/My Drive/TESI/Esempio/COMA/sw_gong_coma/coma/data/CoMA', dataset='CoMA', decay_step=1, device_idx=0, epochs=300, exp_name='interpolation_exp', in_channels=3, latent_channels=8, lr=0.008, lr_decay=0.99, n_threads=4, optimizer='Adam', out_channels=[16, 16, 16, 32], out_dir='/content/drive/My Drive/TESI/Esempio/COMA/sw_gong_coma/coma/out/interpolation_exp', seed=1, split='interpolation', test_exp='bareteeth', weight_decay=0, work_dir='/content/drive/My Drive/TESI/Esempio/COMA/sw_gong_coma/coma')
# Normalizing...
# Done!
# AE(
#   (en_layers): ModuleList(
#     (0): Enblock(
#       (conv): ChebConv(3, 16, K=6, normalization=sym)
#     )
#     (1): Enblock(
#       (conv): ChebConv(16, 16, K=6, normalization=sym)
#     )
#     (2): Enblock(
#       (conv): ChebConv(16, 16, K=6, normalization=sym)
#     )
# ...

# %%
# !python main.py --exp_name 'extrapolation_exp' --split 'extrapolation' --device_idx 0 --test_exp 'bareteeth' \
# Out:
# Traceback (most recent call last):
#   File "main.py", line 8, in <module>
#     import torch_geometric.transforms as T
#   File "/usr/local/lib/python3.6/dist-packages/torch_geometric/__init__.py", line 2, in <module>
#     import torch_geometric.nn
#   File "/usr/local/lib/python3.6/dist-packages/torch_geometric/nn/__init__.py", line 2, in <module>
#     from .data_parallel import DataParallel
#   File "/usr/local/lib/python3.6/dist-packages/torch_geometric/nn/data_parallel.py", line 5, in <module>
#     from torch_geometric.data import Batch
#   File "/usr/local/lib/python3.6/dist-packages/torch_geometric/data/__init__.py", line 1, in <module>
#     from .data import Data
#   File "/usr/local/lib/python3.6/dist-packages/torch_geometric/data/data.py", line 7, in <module>
#     from torch_sparse import coalesce
#   File "/usr/local/lib/python3.6/dist-packages/torch_sparse/__init__.py", line 34, in <module>
#     from .storage import SparseStorage  # noqa
# ...
